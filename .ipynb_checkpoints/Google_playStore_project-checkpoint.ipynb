# %% [markdown]
# # <center> Exploratory Data Analysis On Google Playstore</center>
#
#
# ## Introduction
#
#
#
# We'll use the Google Playstore dataset for our analysis. The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market! you can find the raw data & results here: https://www.kaggle.com/lava18/google-play-store-apps. (👈 Click to Download)
#
# **The Libraries I used in Project are:**
# * Matplotlib <a href='https://matplotlib.org/'> Explore here </a>
# * Seaborn <a href='https://seaborn.pydata.org/'> Explore here </a>
# * Numpy <a href='https://numpy.org/'> Explore here </a>
# * Pandas <a href='https://pandas.pydata.org/'> Explore here </a>
# * Jovian <a href='https://jovian.ml'> Explore here </a>
#
#
# **There are several options for getting the dataset into Jupyter:**
#
# - Download the CSV manually and upload it via Jupyter's GUI
# - Use the `urlretrieve` function from the `urllib.request` to download CSV files from a raw URL directly
# - Use a helper library e.g. [`opendatasets`](https://github.com/JovianML/opendatasets), which contains a collection of curated datasets and provides a function for directly download.
#
# We'll use the `opendatasets` helper library to download the files.

# %% [markdown]
# Now First Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime


# %matplotlib inline

# %%
playStore_data_df = pd.read_csv("googleplaystore.csv")

# %% [markdown]
# Load Googleplaystore data into the dataframe

# %%
playStore_data_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Dataset contains 10841 Rows (Application) And 13 Columns
#
# Lets see How many Columns in the Dataframe

# %%
playStore_data_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# It appears like there are 13 columns in this Dataframe & its parameters of each application

# %%
project_name='Exploratory-data-analysis-on-googleplaystore-data'

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name,file='googleplaystore.csv')
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "harshalzade/exploratory-data-analysis-on-googleplaystore-data" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/harshalzade/exploratory-data-analysis-on-googleplaystore-data
# 'https://jovian.ml/harshalzade/exploratory-data-analysis-on-googleplaystore-data'

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
df = playStore_data_df.copy()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# We can view some basic information about the data frame using the .info method.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Dataset can contain missing data, numerical string value, various cues.
# If we can clean them, we can make easy our analysis.

# %%
df['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %% [markdown]
# ### Category

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# In category column 1.9 is wrong value ,so i have to see correspond values of 1.9

# %%
df[df['Category']=='1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# so we have change value of  category 1.9 into  the nan

# %%
df.loc[10472,'Category'] = np.nan

# %%
df.loc[10470:10474]
# Out:
#                                            App         Category  Rating  \
# 10470                               Jazz Wi-Fi    COMMUNICATION     3.4
# 10471                         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              NaN    19.0
# 10473                  osmino Wi-Fi: free WiFi            TOOLS     4.2
# 10474                             Sat-Fi Voice    COMMUNICATION     3.4
#
#       Reviews    Size     Installs  Type     Price Content Rating  \
# 10470      49    4.0M      10,000+  Free         0       Everyone
# 10471    1042    404k     100,000+  Free         0       Everyone
# 10472    3.0M  1,000+         Free     0  Everyone            NaN
# 10473  134203    4.1M  10,000,000+  Free         0       Everyone
# 10474      37     14M       1,000+  Free         0       Everyone
#
#                   Genres       Last Updated Current Ver   Android Ver
# ...

# %% [markdown]
# ### Rating

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df.Rating.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Reviews

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df[df['Reviews']=='3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      NaN    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df['Reviews']= df.Reviews.replace('3.0M','3000000.0')
df['Reviews']= df.Reviews.replace('0.0','0')

# %%
df['Reviews'] = df.Reviews.astype(float)

# %%
df.loc[10470:10474]
# Out:
#                                            App         Category  Rating  \
# 10470                               Jazz Wi-Fi    COMMUNICATION     3.4
# 10471                         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              NaN    19.0
# 10473                  osmino Wi-Fi: free WiFi            TOOLS     4.2
# 10474                             Sat-Fi Voice    COMMUNICATION     3.4
#
#          Reviews    Size     Installs  Type     Price Content Rating  \
# 10470       49.0    4.0M      10,000+  Free         0       Everyone
# 10471     1042.0    404k     100,000+  Free         0       Everyone
# 10472  3000000.0  1,000+         Free     0  Everyone            NaN
# 10473   134203.0    4.1M  10,000,000+  Free         0       Everyone
# 10474       37.0     14M       1,000+  Free         0       Everyone
#
#                   Genres       Last Updated Current Ver   Android Ver
# ...

# %% [markdown]
# ### Size

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# Here we Convert M(Megabyte) into 1000000 byte and k(kilobyte) into 1000 byte
#
# 'Varies with device' into nan
#
#  and convert value 1000+ into 1000

# %%
df['Size'] = df['Size'].str.replace('M','000000')
df['Size'] = df['Size'].str.replace('k','000')
df['Size'] = df['Size'].replace('1,000+',1000)
df['Size'] = df['Size'].replace('Varies with device',np.nan)
df['Size'] = df['Size'].astype(float)

# %%
df['Size'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Installs

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %% [markdown]
# We can convert str datatype into float and Doing Same process like Size

# %%
df['Installs'] = df['Installs'].str.replace('+','')
df['Installs'] = df['Installs'].str.replace(',','')
df['Installs'] = df['Installs'].replace('Free',np.nan)
df['Installs'] = df['Installs'].astype(float)

# %%
df['Installs'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Type

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %% [markdown]
# ### Price

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price'] = df['Price'].str.replace('$','')
df['Price'] = df['Price'].replace('Everyone',np.nan)
df['Price'] = df['Price'].astype(float)

# %% [markdown]
# Data type of Price is object. I have made similar processes, which I made the in 'Size'.

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,    nan,   1.2 ,   1.04])

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews        Size  Installs  Type  Price Content Rating  \
# 0    159.0  19000000.0   10000.0  Free    0.0       Everyone
# 1    967.0  14000000.0  500000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# ### Last Updated

# %% [markdown]
# Here `Last Update` Datatype is in `str` So, we need to convert it into `Datatime` Datatype

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df['Last Updated'].loc[10472] = np.nan
# Out:
# C:\Users\HARSHAL\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10841, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            9146 non-null   float64
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             1
# Rating            1474
# Reviews              0
# Size              1695
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.describe()
# Out:
#             Rating       Reviews          Size      Installs         Price
# count  9367.000000  1.084100e+04  9.146000e+03  1.084000e+04  10840.000000
# mean      4.193338  4.443887e+05  1.957534e+07  1.546434e+07      1.027368
# std       0.537431  2.927728e+06  2.404320e+07  8.502936e+07     15.949703
# min       1.000000  0.000000e+00  1.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  5.600000e+00  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.300000e+07  1.000000e+05      0.000000
# 75%       4.500000  5.479800e+04  3.000000e+07  5.000000e+06      0.000000
# max      19.000000  7.815831e+07  1.000000e+08  1.000000e+09    400.000000

# %% [markdown]
# There seems to be a problem with the Rating column may contain invalid values due to accidental or intentional errors while responding. A simple fix would be ignore the rows where the value in the Rating column is higher than 5  This can be done using the .drop method, as explained here.

# %%
 df.drop(df[df.Rating > 5].index,inplace=True)

# %%
df.describe()
# Out:
#             Rating       Reviews          Size      Installs         Price
# count  9366.000000  1.084000e+04  9.145000e+03  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05  1.957748e+07  1.546434e+07      1.027368
# std       0.515219  2.927761e+06  2.404364e+07  8.502936e+07     15.949703
# min       1.000000  0.000000e+00  1.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  5.600000e+00  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.300000e+07  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04  3.000000e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.000000e+08  1.000000e+09    400.000000

# %% [markdown]
# You can check the total number of missing values in each column with a single line of code.

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# You could also check the missing values as a percent of all observations.

# %%
df.isnull().sum()*100/len(df)
# Out:
# App                0.000000
# Category           0.000000
# Rating            13.597786
# Reviews            0.000000
# Size              15.636531
# Installs           0.000000
# Type               0.009225
# Price              0.000000
# Content Rating     0.000000
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073801
# Android Ver        0.018450
# dtype: float64

# %% [markdown]
#  **One treatment of missing values is just dropping the observations entirely if the dataset is relatively large and missing cases are few.**
#
#  **Dropping is only advised to be used if missing values are few `(say 0.01–0.5% of our data)`. Percent is just a rule of thumb.**

# %% [markdown]
# #####  In our datasets `Type`,`Current ver`,`Android ver` lies between `(say 0.01–0.5% of our data)` so we drop nan values

# %%
df.dropna(subset=['Type'],inplace=True)
df.dropna(subset=['Current Ver'],inplace=True)
df.dropna(subset=['Android Ver'],inplace=True)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1469
# Reviews              0
# Size              1694
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
df.shape
# Out:
# (10829, 13)

# %% [markdown]
# We've now cleaned up and prepared the dataset for analysis. Let's take a look at sample of rows from the data frame.

# %%
df.sample(10)
# Out:
#                                                    App            Category  \
# 1292                    Runkeeper - GPS Track Run Walk  HEALTH_AND_FITNESS
# 6917                                          BW Ultra        PRODUCTIVITY
# 5880                              NB|AZ Mobile Banking             FINANCE
# 1763                                    Piano Tiles 2™                GAME
# 421                           Ghostery Privacy Browser       COMMUNICATION
# 2706                      Checkout 51: Grocery coupons            SHOPPING
# 6411                     Daily Manga - Comic & Webtoon              COMICS
# 9366                                               EH!           LIFESTYLE
# 4716  W Pro - Weather Forecast & Animated Weather Maps             WEATHER
# 1467     Domofond Real Estate. Buy, rent an apartment.      HOUSE_AND_HOME
#
#       Rating    Reviews        Size     Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
#  All Datatypes of column are Ok,Now good to go for `Exploratory Analysis and Visualization`

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "harshalzade/exploratory-data-analysis-on-googleplaystore-data" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/harshalzade/exploratory-data-analysis-on-googleplaystore-data
# 'https://jovian.ml/harshalzade/exploratory-data-analysis-on-googleplaystore-data'

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %%
import matplotlib
import sys
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# corr() : It returns correlation.
#
# describe (): It returns number of entries, average of entries, outlier values, standart deviation, minimum and maximum entry.

# %%
#correlation map
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# **We can identify the `Application` with the TOP `10` highest number of respondents using the value_counts method.**

# %%
s = df.App.value_counts().head(10)
s
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# 8 Ball Pool                                           7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
# ESPN                                                  7
# Nick                                                  6
# Bleacher Report: sports news, scores, & highlights    6
# Bowmasters                                            6
# slither.io                                            6
# Name: App, dtype: int64

# %%
names = list(s.index)
values = list(s.values)
    

fig,ax = plt.subplots(1, 3, figsize=(20, 8), sharey=True)


ax[0].bar(names, values)
ax[1].scatter(names, values)
ax[2].plot(names, values)

fig.autofmt_xdate(rotation=75)

fig.suptitle('TOP 10 App highest number of respondents')
plt.show()

# %% [markdown]
# **Now we find count of Rating Per Category and Total Review per Category**

# %%
categ_rating = df.groupby('Category').Rating.nunique()
categ_rev = df.groupby('Category').Reviews.sum()

# %%
# Set up 2 x 1 chart group
figCategory, chtCategory = plt.subplots(2, 1, figsize=(20, 15))

# Set up x-axis for 2 charts
srCategoryList = categ_rating.index

# Use the cht for plotting
chtCategory[0].plot(srCategoryList, categ_rating.values, marker='s')
chtCategory[0].set_xlabel('Category')
chtCategory[0].set_ylabel('Rating Count')
chtCategory[0].set_title(' Count Of Rating per Category')
chtCategory[0].set_xticklabels(srCategoryList, rotation=75)


chtCategory[1].plot(srCategoryList, categ_rev.values, marker='s')
chtCategory[1].set_xlabel('Category')
chtCategory[1].set_ylabel('Total Reviews')
chtCategory[1].set_title('Total Reviews per Category')
chtCategory[1].set_xticklabels(srCategoryList, rotation=75)

plt.tight_layout(pad=5)
plt.show()

# %% [markdown]
# **Heat maps display numeric tabular data where the cells are colored depending upon the contained value. Heat maps are great for making trends in this kind of data more readily apparent, particularly when the data is ordered and there is clustering.**

# %% [markdown]
# Here we comapre `Genres` and `Content Rating` with values of `Size`
#
# `For Better View please Zoom the heatmap`

# %%
plt.rcParams['figure.figsize'] = (50.0, 80.0)
plt.rcParams['font.size'] = 28
bg_color = (0.88,0.85,0.95)
plt.rcParams['figure.facecolor'] = bg_color
plt.rcParams['axes.facecolor'] = bg_color
fig, ax = plt.subplots(1)
df_s = pd.pivot_table(data=df,
                    index='Genres',
                    values='Size',
                    columns='Content Rating')
p = sns.heatmap(df_s, cmap='coolwarm',annot=True,
                fmt=".1f",
                annot_kws={'size':25},
                ax=ax)

plt.text(5,30.3, "Heat Map", fontsize = 15, color='Black', fontstyle='italic')
plt.show()

print("For Better View please Zoom the heatmap")
# Out:
# For Better View please Zoom the heatmap

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..

# %% [markdown]
# ## Asking and Answering Questions
#
# TODO

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/zerotopandas-course-project-starter" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/zerotopandas-course-project-starter
# 'https://jovian.ml/aakashns/zerotopandas-course-project-starter'

# %% [markdown]
# ## Inferences and Conclusion
#
# TODO

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "aakashns/zerotopandas-course-project-starter" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/aakashns/zerotopandas-course-project-starter
# 'https://jovian.ml/aakashns/zerotopandas-course-project-starter'

# %% [markdown]
# ## References and Future Work
#
# TODO

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
